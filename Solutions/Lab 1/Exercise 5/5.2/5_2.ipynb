# %%
from PIL import Image
from IPython.display import display

img = Image.open("Requirements-lab1.png")
display(img)
from PIL import ImageDraw

draw = ImageDraw.Draw(img)
draw.text((50, 50), "Exercise 5.2 - Lab 1", fill="red")

display(img)
img.save("Requirements-lab1-annotated.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=907x482>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=907x482>
