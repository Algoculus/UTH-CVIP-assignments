# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("image.jpg", cv2.IMREAD_GRAYSCALE)
if img is None:
    print("Error: Could not load image. Please check the file path.")
else:
    print(f"Image loaded successfully. Shape: {img.shape}")
# Out:
# Image loaded successfully. Shape: (4320, 7680)

# %%
def negative_transform(image):
    return 255 - image

# %%
negative_img = negative_transform(img)

plt.figure(figsize=(8,4))
plt.subplot(1,2,1); plt.title("Original"); plt.imshow(img, cmap='gray')
plt.subplot(1,2,2); plt.title("Negative"); plt.imshow(negative_img, cmap='gray')
plt.show()
